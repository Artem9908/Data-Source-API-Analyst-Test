# %%
# Cell 1: Import Libraries
import requests
import json
import time
from getpass import getpass

# %%
# Cell 2: Authentication
GITHUB_TOKEN = getpass('Enter your GitHub Personal Access Token: ')
# Out:
# Enter your GitHub Personal Access Token: ··········

# %%
# Cell 3: Set up headers
headers = {
    'Authorization': f'token {GITHUB_TOKEN}',
    'Accept': 'application/vnd.github+json',
    'X-GitHub-Api-Version': '2022-11-28'
}

# %%
# Cell 4: Function to search repositories
def search_repositories(query, per_page=30, page=1):
    url = 'https://api.github.com/search/repositories'
    params = {
        'q': query,
        'per_page': per_page,
        'page': page
    }
    response = requests.get(url, headers=headers, params=params)
    response.raise_for_status()
    return response.json()

# %%
# Cell 5: Test search_repositories function
query = 'machine learning'
result = search_repositories(query)
print(json.dumps(result, indent=2))
# Out:
# {
#   "total_count": 715589,
#   "incomplete_results": false,
#   "items": [
#     {
#       "id": 21872392,
#       "node_id": "MDEwOlJlcG9zaXRvcnkyMTg3MjM5Mg==",
#       "name": "awesome-machine-learning",
#       "full_name": "josephmisiti/awesome-machine-learning",
#       "private": false,
#       "owner": {
#         "login": "josephmisiti",
#         "id": 246302,
#         "node_id": "MDQ6VXNlcjI0NjMwMg==",
#         "avatar_url": "https://avatars.githubusercontent.com/u/246302?v=4",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/josephmisiti",
#         "html_url": "https://github.com/josephmisiti",
#         "followers_url": "https://api.github.com/users/josephmisiti/followers",
#         "following_url": "https://api.github.com/users/josephmisiti/following{/other_user}",
#         "gists_url": "https://api.github.com/users/josephmisiti/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/josephmisiti/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/josephmisiti/subscriptions",
#         "organizations_url": "https://api.github.com/users/josephmisiti/orgs",
#         "repos_url": "https://api.github.com/users/josephmisiti/repos",
#         "events_url": "https://api.github.com/users/josephmisiti/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/josephmisiti/received_events",
#         "type": "User",
#         "user_view_type": "public",
#         "site_admin": false
#       },
#       "html_url": "https://github.com/josephmisiti/awesome-machine-learning",
#       "description": "A curated list of awesome Machine Learning frameworks, libraries and software.",
#       "fork": false,
#       "url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning",
#       "forks_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/forks",
#       "keys_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/keys{/key_id}",
#       "collaborators_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/collaborators{/collaborator}",
#       "teams_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/teams",
#       "hooks_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/hooks",
#       "issue_events_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/issues/events{/number}",
#       "events_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/events",
#       "assignees_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/assignees{/user}",
#       "branches_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/branches{/branch}",
#       "tags_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/tags",
#       "blobs_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/git/blobs{/sha}",
#       "git_tags_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/git/tags{/sha}",
#       "git_refs_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/git/refs{/sha}",
#       "trees_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/git/trees{/sha}",
#       "statuses_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/statuses/{sha}",
#       "languages_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/languages",
#       "stargazers_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/stargazers",
#       "contributors_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/contributors",
#       "subscribers_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/subscribers",
#       "subscription_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/subscription",
#       "commits_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/commits{/sha}",
#       "git_commits_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/git/commits{/sha}",
#       "comments_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/comments{/number}",
#       "issue_comment_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/issues/comments{/number}",
#       "contents_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/contents/{+path}",
#       "compare_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/compare/{base}...{head}",
#       "merges_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/merges",
#       "archive_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/{archive_format}{/ref}",
#       "downloads_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/downloads",
#       "issues_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/issues{/number}",
#       "pulls_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/pulls{/number}",
#       "milestones_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/milestones{/number}",
#       "notifications_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/notifications{?since,all,participating}",
#       "labels_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/labels{/name}",
#       "releases_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/releases{/id}",
#       "deployments_url": "https://api.github.com/repos/josephmisiti/awesome-machine-learning/deployments",
#       "created_at": "2014-07-15T19:11:19Z",
#       "updated_at": "2024-11-26T17:06:59Z",
#       "pushed_at": "2024-11-11T16:08:31Z",
#       "git_url": "git://github.com/josephmisiti/awesome-machine-learning.git",
#       "ssh_url": "git@github.com:josephmisiti/awesome-machine-learning.git",
#       "clone_url": "https://github.com/josephmisiti/awesome-machine-learning.git",
#       "svn_url": "https://github.com/josephmisiti/awesome-machine-learning",
#       "homepage": null,
#       "size": 2967,
#       "stargazers_count": 66110,
#       "watchers_count": 66110,
#       "language": "Python",
#       "has_issues": true,
#       "has_projects": false,
#       "has_downloads": true,
#       "has_wiki": false,
#       "has_pages": true,
#       "has_discussions": false,
#       "forks_count": 14653,
#       "mirror_url": null,
#       "archived": false,
#       "disabled": false,
#       "open_issues_count": 9,
#       "license": {
#         "key": "other",
#         "name": "Other",
#         "spdx_id": "NOASSERTION",
#         "url": null,
#         "node_id": "MDc6TGljZW5zZTA="
#       },
#       "allow_forking": true,
#       "is_template": false,
#       "web_commit_signoff_required": false,
#       "topics": [],
#       "visibility": "public",
#       "forks": 14653,
#       "open_issues": 9,
#       "watchers": 66110,
#       "default_branch": "master",
#       "permissions": {
#         "admin": false,
#         "maintain": false,
#         "push": false,
#         "triage": false,
#         "pull": true
#       },
#       "score": 1.0
#     },
#     {
#       "id": 27595858,
#       "node_id": "MDEwOlJlcG9zaXRvcnkyNzU5NTg1OA==",
#       "name": "MachineLearning",
#       "full_name": "wepe/MachineLearning",
#       "private": false,
#       "owner": {
#         "login": "wepe",
#         "id": 9136322,
#         "node_id": "MDQ6VXNlcjkxMzYzMjI=",
#         "avatar_url": "https://avatars.githubusercontent.com/u/9136322?v=4",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/wepe",
#         "html_url": "https://github.com/wepe",
#         "followers_url": "https://api.github.com/users/wepe/followers",
#         "following_url": "https://api.github.com/users/wepe/following{/other_user}",
#         "gists_url": "https://api.github.com/users/wepe/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/wepe/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/wepe/subscriptions",
#         "organizations_url": "https://api.github.com/users/wepe/orgs",
#         "repos_url": "https://api.github.com/users/wepe/repos",
#         "events_url": "https://api.github.com/users/wepe/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/wepe/received_events",
#         "type": "User",
#         "user_view_type": "public",
#         "site_admin": false
#       },
#       "html_url": "https://github.com/wepe/MachineLearning",
#       "description": "Basic Machine Learning and Deep Learning",
#       "fork": false,
#       "url": "https://api.github.com/repos/wepe/MachineLearning",
#       "forks_url": "https://api.github.com/repos/wepe/MachineLearning/forks",
#       "keys_url": "https://api.github.com/repos/wepe/MachineLearning/keys{/key_id}",
#       "collaborators_url": "https://api.github.com/repos/wepe/MachineLearning/collaborators{/collaborator}",
#       "teams_url": "https://api.github.com/repos/wepe/MachineLearning/teams",
#       "hooks_url": "https://api.github.com/repos/wepe/MachineLearning/hooks",
#       "issue_events_url": "https://api.github.com/repos/wepe/MachineLearning/issues/events{/number}",
#       "events_url": "https://api.github.com/repos/wepe/MachineLearning/events",
#       "assignees_url": "https://api.github.com/repos/wepe/MachineLearning/assignees{/user}",
#       "branches_url": "https://api.github.com/repos/wepe/MachineLearning/branches{/branch}",
#       "tags_url": "https://api.github.com/repos/wepe/MachineLearning/tags",
#       "blobs_url": "https://api.github.com/repos/wepe/MachineLearning/git/blobs{/sha}",
#       "git_tags_url": "https://api.github.com/repos/wepe/MachineLearning/git/tags{/sha}",
#       "git_refs_url": "https://api.github.com/repos/wepe/MachineLearning/git/refs{/sha}",
#       "trees_url": "https://api.github.com/repos/wepe/MachineLearning/git/trees{/sha}",
#       "statuses_url": "https://api.github.com/repos/wepe/MachineLearning/statuses/{sha}",
#       "languages_url": "https://api.github.com/repos/wepe/MachineLearning/languages",
#       "stargazers_url": "https://api.github.com/repos/wepe/MachineLearning/stargazers",
#       "contributors_url": "https://api.github.com/repos/wepe/MachineLearning/contributors",
#       "subscribers_url": "https://api.github.com/repos/wepe/MachineLearning/subscribers",
#       "subscription_url": "https://api.github.com/repos/wepe/MachineLearning/subscription",
#       "commits_url": "https://api.github.com/repos/wepe/MachineLearning/commits{/sha}",
#       "git_commits_url": "https://api.github.com/repos/wepe/MachineLearning/git/commits{/sha}",
#       "comments_url": "https://api.github.com/repos/wepe/MachineLearning/comments{/number}",
#       "issue_comment_url": "https://api.github.com/repos/wepe/MachineLearning/issues/comments{/number}",
#       "contents_url": "https://api.github.com/repos/wepe/MachineLearning/contents/{+path}",
#       "compare_url": "https://api.github.com/repos/wepe/MachineLearning/compare/{base}...{head}",
#       "merges_url": "https://api.github.com/repos/wepe/MachineLearning/merges",
#       "archive_url": "https://api.github.com/repos/wepe/MachineLearning/{archive_format}{/ref}",
#       "downloads_url": "https://api.github.com/repos/wepe/MachineLearning/downloads",
#       "issues_url": "https://api.github.com/repos/wepe/MachineLearning/issues{/number}",
#       "pulls_url": "https://api.github.com/repos/wepe/MachineLearning/pulls{/number}",
#       "milestones_url": "https://api.github.com/repos/wepe/MachineLearning/milestones{/number}",
#       "notifications_url": "https://api.github.com/repos/wepe/MachineLearning/notifications{?since,all,participating}",
#       "labels_url": "https://api.github.com/repos/wepe/MachineLearning/labels{/name}",
#       "releases_url": "https://api.github.com/repos/wepe/MachineLearning/releases{/id}",
#       "deployments_url": "https://api.github.com/repos/wepe/MachineLearning/deployments",
#       "created_at": "2014-12-05T14:53:17Z",
#       "updated_at": "2024-11-26T06:59:22Z",
#       "pushed_at": "2024-06-15T23:28:32Z",
#       "git_url": "git://github.com/wepe/MachineLearning.git",
#       "ssh_url": "git@github.com:wepe/MachineLearning.git",
#       "clone_url": "https://github.com/wepe/MachineLearning.git",
#       "svn_url": "https://github.com/wepe/MachineLearning",
#       "homepage": "",
#       "size": 8209,
#       "stargazers_count": 5252,
#       "watchers_count": 5252,
#       "language": "Python",
#       "has_issues": true,
#       "has_projects": true,
#       "has_downloads": true,
#       "has_wiki": true,
#       "has_pages": false,
#       "has_discussions": false,
#       "forks_count": 3171,
#       "mirror_url": null,
#       "archived": false,
#       "disabled": false,
#       "open_issues_count": 42,
#       "license": null,
#       "allow_forking": true,
#       "is_template": false,
#       "web_commit_signoff_required": false,
#       "topics": [],
#       "visibility": "public",
#       "forks": 3171,
#       "open_issues": 42,
#       "watchers": 5252,
#       "default_branch": "master",
#       "permissions": {
#         "admin": false,
#         "maintain": false,
#         "push": false,
#         "triage": false,
#         "pull": true
#       },
#       "score": 1.0
#     },
#     {
#       "id": 86140645,
#       "node_id": "MDEwOlJlcG9zaXRvcnk4NjE0MDY0NQ==",
#       "name": "Machine-Learning",
#       "full_name": "Jack-Cherish/Machine-Learning",
#       "private": false,
#       "owner": {
#         "login": "Jack-Cherish",
#         "id": 16872370,
#         "node_id": "MDQ6VXNlcjE2ODcyMzcw",
#         "avatar_url": "https://avatars.githubusercontent.com/u/16872370?v=4",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/Jack-Cherish",
#         "html_url": "https://github.com/Jack-Cherish",
#         "followers_url": "https://api.github.com/users/Jack-Cherish/followers",
#         "following_url": "https://api.github.com/users/Jack-Cherish/following{/other_user}",
#         "gists_url": "https://api.github.com/users/Jack-Cherish/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/Jack-Cherish/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/Jack-Cherish/subscriptions",
#         "organizations_url": "https://api.github.com/users/Jack-Cherish/orgs",
#         "repos_url": "https://api.github.com/users/Jack-Cherish/repos",
#         "events_url": "https://api.github.com/users/Jack-Cherish/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/Jack-Cherish/received_events",
#         "type": "User",
#         "user_view_type": "public",
#         "site_admin": false
#       },
#       "html_url": "https://github.com/Jack-Cherish/Machine-Learning",
#       "description": ":zap:\u673a\u5668\u5b66\u4e60\u5b9e\u6218\uff08Python3\uff09\uff1akNN\u3001\u51b3\u7b56\u6811\u3001\u8d1d\u53f6\u65af\u3001\u903b\u8f91\u56de\u5f52\u3001SVM\u3001\u7ebf\u6027\u56de\u5f52\u3001\u6811\u56de\u5f52",
#       "fork": false,
#       "url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning",
#       "forks_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/forks",
#       "keys_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/keys{/key_id}",
#       "collaborators_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/collaborators{/collaborator}",
#       "teams_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/teams",
#       "hooks_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/hooks",
#       "issue_events_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/issues/events{/number}",
#       "events_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/events",
#       "assignees_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/assignees{/user}",
#       "branches_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/branches{/branch}",
#       "tags_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/tags",
#       "blobs_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/git/blobs{/sha}",
#       "git_tags_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/git/tags{/sha}",
#       "git_refs_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/git/refs{/sha}",
#       "trees_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/git/trees{/sha}",
#       "statuses_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/statuses/{sha}",
#       "languages_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/languages",
#       "stargazers_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/stargazers",
#       "contributors_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/contributors",
#       "subscribers_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/subscribers",
#       "subscription_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/subscription",
#       "commits_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/commits{/sha}",
#       "git_commits_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/git/commits{/sha}",
#       "comments_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/comments{/number}",
#       "issue_comment_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/issues/comments{/number}",
#       "contents_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/contents/{+path}",
#       "compare_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/compare/{base}...{head}",
#       "merges_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/merges",
#       "archive_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/{archive_format}{/ref}",
#       "downloads_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/downloads",
#       "issues_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/issues{/number}",
#       "pulls_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/pulls{/number}",
#       "milestones_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/milestones{/number}",
#       "notifications_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/notifications{?since,all,participating}",
#       "labels_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/labels{/name}",
#       "releases_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/releases{/id}",
#       "deployments_url": "https://api.github.com/repos/Jack-Cherish/Machine-Learning/deployments",
#       "created_at": "2017-03-25T07:32:37Z",
#       "updated_at": "2024-11-26T17:02:42Z",
#       "pushed_at": "2024-07-12T11:28:35Z",
#       "git_url": "git://github.com/Jack-Cherish/Machine-Learning.git",
#       "ssh_url": "git@github.com:Jack-Cherish/Machine-Learning.git",
#       "clone_url": "https://github.com/Jack-Cherish/Machine-Learning.git",
#       "svn_url": "https://github.com/Jack-Cherish/Machine-Learning",
#       "homepage": "https://cuijiahua.com/blog/ml/",
#       "size": 1132,
#       "stargazers_count": 9190,
#       "watchers_count": 9190,
#       "language": "Python",
#       "has_issues": true,
#       "has_projects": false,
#       "has_downloads": true,
#       "has_wiki": false,
#       "has_pages": false,
#       "has_discussions": false,
#       "forks_count": 5076,
#       "mirror_url": null,
#       "archived": false,
#       "disabled": false,
#       "open_issues_count": 6,
#       "license": null,
#       "allow_forking": true,
#       "is_template": false,
#       "web_commit_signoff_required": false,
#       "topics": [
#         "adaboost",
#         "adaboost-algorithm",
#         "decision-tree",
#         "knn",
#         "logistic",
#         "machine-learning",
#         "navie-bayes-algorithm",
#         "python",
#         "python3",
#         "regression",
#         "smo",
#         "svm"
#       ],
#       "visibility": "public",
#       "forks": 5076,
#       "open_issues": 6,
#       "watchers": 9190,
#       "default_branch": "master",
#       "permissions": {
#         "admin": false,
#         "maintain": false,
#         "push": false,
#         "triage": false,
#         "pull": true
#       },
#       "score": 1.0
#     },
#     {
#       "id": 71154529,
#       "node_id": "MDEwOlJlcG9zaXRvcnk3MTE1NDUyOQ==",
#       "name": "MachineLearning_Python",
#       "full_name": "lawlite19/MachineLearning_Python",
#       "private": false,
#       "owner": {
#         "login": "lawlite19",
#         "id": 14356062,
#         "node_id": "MDQ6VXNlcjE0MzU2MDYy",
#         "avatar_url": "https://avatars.githubusercontent.com/u/14356062?v=4",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/lawlite19",
#         "html_url": "https://github.com/lawlite19",
#         "followers_url": "https://api.github.com/users/lawlite19/followers",
#         "following_url": "https://api.github.com/users/lawlite19/following{/other_user}",
#         "gists_url": "https://api.github.com/users/lawlite19/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/lawlite19/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/lawlite19/subscriptions",
#         "organizations_url": "https://api.github.com/users/lawlite19/orgs",
#         "repos_url": "https://api.github.com/users/lawlite19/repos",
#         "events_url": "https://api.github.com/users/lawlite19/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/lawlite19/received_events",
#         "type": "User",
#         "user_view_type": "public",
#         "site_admin": false
#       },
#       "html_url": "https://github.com/lawlite19/MachineLearning_Python",
#       "description": "\u673a\u5668\u5b66\u4e60\u7b97\u6cd5python\u5b9e\u73b0",
#       "fork": false,
#       "url": "https://api.github.com/repos/lawlite19/MachineLearning_Python",
#       "forks_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/forks",
#       "keys_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/keys{/key_id}",
#       "collaborators_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/collaborators{/collaborator}",
#       "teams_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/teams",
#       "hooks_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/hooks",
#       "issue_events_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/issues/events{/number}",
#       "events_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/events",
#       "assignees_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/assignees{/user}",
#       "branches_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/branches{/branch}",
#       "tags_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/tags",
#       "blobs_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/git/blobs{/sha}",
#       "git_tags_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/git/tags{/sha}",
#       "git_refs_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/git/refs{/sha}",
#       "trees_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/git/trees{/sha}",
#       "statuses_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/statuses/{sha}",
#       "languages_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/languages",
#       "stargazers_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/stargazers",
#       "contributors_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/contributors",
#       "subscribers_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/subscribers",
#       "subscription_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/subscription",
#       "commits_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/commits{/sha}",
#       "git_commits_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/git/commits{/sha}",
#       "comments_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/comments{/number}",
#       "issue_comment_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/issues/comments{/number}",
#       "contents_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/contents/{+path}",
#       "compare_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/compare/{base}...{head}",
#       "merges_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/merges",
#       "archive_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/{archive_format}{/ref}",
#       "downloads_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/downloads",
#       "issues_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/issues{/number}",
#       "pulls_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/pulls{/number}",
#       "milestones_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/milestones{/number}",
#       "notifications_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/notifications{?since,all,participating}",
#       "labels_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/labels{/name}",
#       "releases_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/releases{/id}",
#       "deployments_url": "https://api.github.com/repos/lawlite19/MachineLearning_Python/deployments",
#       "created_at": "2016-10-17T15:44:59Z",
#       "updated_at": "2024-11-26T17:02:04Z",
#       "pushed_at": "2024-05-20T17:21:57Z",
#       "git_url": "git://github.com/lawlite19/MachineLearning_Python.git",
#       "ssh_url": "git@github.com:lawlite19/MachineLearning_Python.git",
#       "clone_url": "https://github.com/lawlite19/MachineLearning_Python.git",
#       "svn_url": "https://github.com/lawlite19/MachineLearning_Python",
#       "homepage": "",
#       "size": 28264,
#       "stargazers_count": 7311,
#       "watchers_count": 7311,
#       "language": "Python",
#       "has_issues": true,
#       "has_projects": true,
#       "has_downloads": true,
#       "has_wiki": true,
#       "has_pages": false,
#       "has_discussions": false,
#       "forks_count": 2436,
#       "mirror_url": null,
#       "archived": false,
#       "disabled": false,
#       "open_issues_count": 12,
#       "license": {
#         "key": "mit",
#         "name": "MIT License",
#         "spdx_id": "MIT",
#         "url": "https://api.github.com/licenses/mit",
#         "node_id": "MDc6TGljZW5zZTEz"
#       },
#       "allow_forking": true,
#       "is_template": false,
#       "web_commit_signoff_required": false,
#       "topics": [],
#       "visibility": "public",
#       "forks": 2436,
#       "open_issues": 12,
#       "watchers": 7311,
#       "default_branch": "master",
#       "permissions": {
#         "admin": false,
#         "maintain": false,
#         "push": false,
#         "triage": false,
#         "pull": true
#       },
#       "score": 1.0
#     },
#     {
#       "id": 50450433,
#       "node_id": "MDEwOlJlcG9zaXRvcnk1MDQ1MDQzMw==",
#       "name": "machine-learning",
#       "full_name": "udacity/machine-learning",
#       "private": false,
#       "owner": {
#         "login": "udacity",
#         "id": 1916665,
#         "node_id": "MDEyOk9yZ2FuaXphdGlvbjE5MTY2NjU=",
#         "avatar_url": "https://avatars.githubusercontent.com/u/1916665?v=4",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/udacity",
#         "html_url": "https://github.com/udacity",
#         "followers_url": "https://api.github.com/users/udacity/followers",
#         "following_url": "https://api.github.com/users/udacity/following{/other_user}",
#         "gists_url": "https://api.github.com/users/udacity/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/udacity/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/udacity/subscriptions",
#         "organizations_url": "https://api.github.com/users/udacity/orgs",
#         "repos_url": "https://api.github.com/users/udacity/repos",
#         "events_url": "https://api.github.com/users/udacity/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/udacity/received_events",
#         "type": "Organization",
#         "user_view_type": "public",
#         "site_admin": false
#       },
#       "html_url": "https://github.com/udacity/machine-learning",
#       "description": "Content for Udacity's Machine Learning curriculum",
#       "fork": false,
#       "url": "https://api.github.com/repos/udacity/machine-learning",
#       "forks_url": "https://api.github.com/repos/udacity/machine-learning/forks",
#       "keys_url": "https://api.github.com/repos/udacity/machine-learning/keys{/key_id}",
#       "collaborators_url": "https://api.github.com/repos/udacity/machine-learning/collaborators{/collaborator}",
#       "teams_url": "https://api.github.com/repos/udacity/machine-learning/teams",
#       "hooks_url": "https://api.github.com/repos/udacity/machine-learning/hooks",
#       "issue_events_url": "https://api.github.com/repos/udacity/machine-learning/issues/events{/number}",
#       "events_url": "https://api.github.com/repos/udacity/machine-learning/events",
#       "assignees_url": "https://api.github.com/repos/udacity/machine-learning/assignees{/user}",
#       "branches_url": "https://api.github.com/repos/udacity/machine-learning/branches{/branch}",
#       "tags_url": "https://api.github.com/repos/udacity/machine-learning/tags",
#       "blobs_url": "https://api.github.com/repos/udacity/machine-learning/git/blobs{/sha}",
#       "git_tags_url": "https://api.github.com/repos/udacity/machine-learning/git/tags{/sha}",
#       "git_refs_url": "https://api.github.com/repos/udacity/machine-learning/git/refs{/sha}",
#       "trees_url": "https://api.github.com/repos/udacity/machine-learning/git/trees{/sha}",
#       "statuses_url": "https://api.github.com/repos/udacity/machine-learning/statuses/{sha}",
#       "languages_url": "https://api.github.com/repos/udacity/machine-learning/languages",
#       "stargazers_url": "https://api.github.com/repos/udacity/machine-learning/stargazers",
#       "contributors_url": "https://api.github.com/repos/udacity/machine-learning/contributors",
#       "subscribers_url": "https://api.github.com/repos/udacity/machine-learning/subscribers",
#       "subscription_url": "https://api.github.com/repos/udacity/machine-learning/subscription",
#       "commits_url": "https://api.github.com/repos/udacity/machine-learning/commits{/sha}",
#       "git_commits_url": "https://api.github.com/repos/udacity/machine-learning/git/commits{/sha}",
#       "comments_url": "https://api.github.com/repos/udacity/machine-learning/comments{/number}",
#       "issue_comment_url": "https://api.github.com/repos/udacity/machine-learning/issues/comments{/number}",
#       "contents_url": "https://api.github.com/repos/udacity/machine-learning/contents/{+path}",
#       "compare_url": "https://api.github.com/repos/udacity/machine-learning/compare/{base}...{head}",
#       "merges_url": "https://api.github.com/repos/udacity/machine-learning/merges",
#       "archive_url": "https://api.github.com/repos/udacity/machine-learning/{archive_format}{/ref}",
#       "downloads_url": "https://api.github.com/repos/udacity/machine-learning/downloads",
#       "issues_url": "https://api.github.com/repos/udacity/machine-learning/issues{/number}",
#       "pulls_url": "https://api.github.com/repos/udacity/machine-learning/pulls{/number}",
#       "milestones_url": "https://api.github.com/repos/udacity/machine-learning/milestones{/number}",
#       "notifications_url": "https://api.github.com/repos/udacity/machine-learning/notifications{?since,all,participating}",
#       "labels_url": "https://api.github.com/repos/udacity/machine-learning/labels{/name}",
#       "releases_url": "https://api.github.com/repos/udacity/machine-learning/releases{/id}",
#       "deployments_url": "https://api.github.com/repos/udacity/machine-learning/deployments",
#       "created_at": "2016-01-26T18:41:03Z",
#       "updated_at": "2024-11-26T08:13:07Z",
#       "pushed_at": "2022-02-24T12:14:00Z",
#       "git_url": "git://github.com/udacity/machine-learning.git",
#       "ssh_url": "git@github.com:udacity/machine-learning.git",
#       "clone_url": "https://github.com/udacity/machine-learning.git",
#       "svn_url": "https://github.com/udacity/machine-learning",
#       "homepage": null,
#       "size": 36346,
#       "stargazers_count": 3942,
#       "watchers_count": 3942,
#       "language": "Jupyter Notebook",
#       "has_issues": true,
#       "has_projects": true,
#       "has_downloads": true,
#       "has_wiki": true,
#       "has_pages": false,
#       "has_discussions": false,
#       "forks_count": 6345,
#       "mirror_url": null,
#       "archived": true,
#       "disabled": false,
#       "open_issues_count": 0,
#       "license": null,
#       "allow_forking": true,
#       "is_template": false,
#       "web_commit_signoff_required": false,
#       "topics": [],
#       "visibility": "public",
#       "forks": 6345,
#       "open_issues": 0,
#       "watchers": 3942,
#       "default_branch": "master",
#       "permissions": {
#         "admin": false,
#         "maintain": false,
#         "push": false,
#         "triage": false,
#         "pull": true
#       },
#       "score": 1.0
#     },
#     {
#       "id": 145148726,
#       "node_id": "MDEwOlJlcG9zaXRvcnkxNDUxNDg3MjY=",
#       "name": "MachineLearningNotebooks",
#       "full_name": "Azure/MachineLearningNotebooks",
#       "private": false,
#       "owner": {
#         "login": "Azure",
#         "id": 6844498,
#         "node_id": "MDEyOk9yZ2FuaXphdGlvbjY4NDQ0OTg=",
#         "avatar_url": "https://avatars.githubusercontent.com/u/6844498?v=4",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/Azure",
#         "html_url": "https://github.com/Azure",
#         "followers_url": "https://api.github.com/users/Azure/followers",
#         "following_url": "https://api.github.com/users/Azure/following{/other_user}",
#         "gists_url": "https://api.github.com/users/Azure/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/Azure/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/Azure/subscriptions",
#         "organizations_url": "https://api.github.com/users/Azure/orgs",
#         "repos_url": "https://api.github.com/users/Azure/repos",
#         "events_url": "https://api.github.com/users/Azure/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/Azure/received_events",
#         "type": "Organization",
#         "user_view_type": "public",
#         "site_admin": false
#       },
#       "html_url": "https://github.com/Azure/MachineLearningNotebooks",
#       "description": "Python notebooks with ML and deep learning examples with Azure Machine Learning Python SDK | Microsoft",
#       "fork": false,
#       "url": "https://api.github.com/repos/Azure/MachineLearningNotebooks",
#       "forks_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/forks",
#       "keys_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/keys{/key_id}",
#       "collaborators_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/collaborators{/collaborator}",
#       "teams_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/teams",
#       "hooks_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/hooks",
#       "issue_events_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/issues/events{/number}",
#       "events_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/events",
#       "assignees_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/assignees{/user}",
#       "branches_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/branches{/branch}",
#       "tags_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/tags",
#       "blobs_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/git/blobs{/sha}",
#       "git_tags_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/git/tags{/sha}",
#       "git_refs_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/git/refs{/sha}",
#       "trees_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/git/trees{/sha}",
#       "statuses_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/statuses/{sha}",
#       "languages_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/languages",
#       "stargazers_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/stargazers",
#       "contributors_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/contributors",
#       "subscribers_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/subscribers",
#       "subscription_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/subscription",
#       "commits_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/commits{/sha}",
#       "git_commits_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/git/commits{/sha}",
#       "comments_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/comments{/number}",
#       "issue_comment_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/issues/comments{/number}",
#       "contents_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/contents/{+path}",
#       "compare_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/compare/{base}...{head}",
#       "merges_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/merges",
#       "archive_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/{archive_format}{/ref}",
#       "downloads_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/downloads",
#       "issues_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/issues{/number}",
#       "pulls_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/pulls{/number}",
#       "milestones_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/milestones{/number}",
#       "notifications_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/notifications{?since,all,participating}",
#       "labels_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/labels{/name}",
#       "releases_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/releases{/id}",
#       "deployments_url": "https://api.github.com/repos/Azure/MachineLearningNotebooks/deployments",
#       "created_at": "2018-08-17T17:29:14Z",
#       "updated_at": "2024-11-26T08:42:53Z",
#       "pushed_at": "2024-11-04T17:20:56Z",
#       "git_url": "git://github.com/Azure/MachineLearningNotebooks.git",
#       "ssh_url": "git@github.com:Azure/MachineLearningNotebooks.git",
#       "clone_url": "https://github.com/Azure/MachineLearningNotebooks.git",
#       "svn_url": "https://github.com/Azure/MachineLearningNotebooks",
#       "homepage": "https://docs.microsoft.com/azure/machine-learning/service/",
#       "size": 78294,
#       "stargazers_count": 4105,
#       "watchers_count": 4105,
#       "language": "Jupyter Notebook",
#       "has_issues": true,
#       "has_projects": false,
#       "has_downloads": true,
#       "has_wiki": false,
#       "has_pages": false,
#       "has_discussions": false,
#       "forks_count": 2523,
#       "mirror_url": null,
#       "archived": false,
#       "disabled": false,
#       "open_issues_count": 393,
#       "license": {
#         "key": "mit",
#         "name": "MIT License",
#         "spdx_id": "MIT",
#         "url": "https://api.github.com/licenses/mit",
#         "node_id": "MDc6TGljZW5zZTEz"
#       },
#       "allow_forking": true,
#       "is_template": false,
#       "web_commit_signoff_required": false,
#       "topics": [
#         "azure",
#         "azure-machine-learning",
#         "azure-ml",
#         "azureml",
#         "data-science",
#         "deep-learning",
#         "machine-learning",
#         "notebook"
#       ],
#       "visibility": "public",
#       "forks": 2523,
#       "open_issues": 393,
#       "watchers": 4105,
#       "default_branch": "master",
#       "permissions": {
#         "admin": false,
#         "maintain": false,
#         "push": false,
#         "triage": false,
#         "pull": true
#       },
#       "score": 1.0
#     },
#     {
#       "id": 22489033,
#       "node_id": "MDEwOlJlcG9zaXRvcnkyMjQ4OTAzMw==",
#       "name": "machine_learning_examples",
#       "full_name": "lazyprogrammer/machine_learning_examples",
#       "private": false,
#       "owner": {
#         "login": "lazyprogrammer",
#         "id": 1301971,
#         "node_id": "MDQ6VXNlcjEzMDE5NzE=",
#         "avatar_url": "https://avatars.githubusercontent.com/u/1301971?v=4",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/lazyprogrammer",
#         "html_url": "https://github.com/lazyprogrammer",
#         "followers_url": "https://api.github.com/users/lazyprogrammer/followers",
#         "following_url": "https://api.github.com/users/lazyprogrammer/following{/other_user}",
#         "gists_url": "https://api.github.com/users/lazyprogrammer/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/lazyprogrammer/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/lazyprogrammer/subscriptions",
#         "organizations_url": "https://api.github.com/users/lazyprogrammer/orgs",
#         "repos_url": "https://api.github.com/users/lazyprogrammer/repos",
#         "events_url": "https://api.github.com/users/lazyprogrammer/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/lazyprogrammer/received_events",
#         "type": "User",
#         "user_view_type": "public",
#         "site_admin": false
#       },
#       "html_url": "https://github.com/lazyprogrammer/machine_learning_examples",
#       "description": "A collection of machine learning examples and tutorials.",
#       "fork": false,
#       "url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples",
#       "forks_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/forks",
#       "keys_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/keys{/key_id}",
#       "collaborators_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/collaborators{/collaborator}",
#       "teams_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/teams",
#       "hooks_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/hooks",
#       "issue_events_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/issues/events{/number}",
#       "events_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/events",
#       "assignees_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/assignees{/user}",
#       "branches_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/branches{/branch}",
#       "tags_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/tags",
#       "blobs_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/git/blobs{/sha}",
#       "git_tags_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/git/tags{/sha}",
#       "git_refs_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/git/refs{/sha}",
#       "trees_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/git/trees{/sha}",
#       "statuses_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/statuses/{sha}",
#       "languages_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/languages",
#       "stargazers_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/stargazers",
#       "contributors_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/contributors",
#       "subscribers_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/subscribers",
#       "subscription_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/subscription",
#       "commits_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/commits{/sha}",
#       "git_commits_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/git/commits{/sha}",
#       "comments_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/comments{/number}",
#       "issue_comment_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/issues/comments{/number}",
#       "contents_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/contents/{+path}",
#       "compare_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/compare/{base}...{head}",
#       "merges_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/merges",
#       "archive_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/{archive_format}{/ref}",
#       "downloads_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/downloads",
#       "issues_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/issues{/number}",
#       "pulls_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/pulls{/number}",
#       "milestones_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/milestones{/number}",
#       "notifications_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/notifications{?since,all,participating}",
#       "labels_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/labels{/name}",
#       "releases_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/releases{/id}",
#       "deployments_url": "https://api.github.com/repos/lazyprogrammer/machine_learning_examples/deployments",
#       "created_at": "2014-07-31T23:40:45Z",
#       "updated_at": "2024-11-26T06:59:30Z",
#       "pushed_at": "2024-10-22T10:04:41Z",
#       "git_url": "git://github.com/lazyprogrammer/machine_learning_examples.git",
#       "ssh_url": "git@github.com:lazyprogrammer/machine_learning_examples.git",
#       "clone_url": "https://github.com/lazyprogrammer/machine_learning_examples.git",
#       "svn_url": "https://github.com/lazyprogrammer/machine_learning_examples",
#       "homepage": "https://lazyprogrammer.me",
#       "size": 23543,
#       "stargazers_count": 8392,
#       "watchers_count": 8392,
#       "language": "Python",
#       "has_issues": true,
#       "has_projects": true,
#       "has_downloads": true,
#       "has_wiki": true,
#       "has_pages": true,
#       "has_discussions": false,
#       "forks_count": 6349,
#       "mirror_url": null,
#       "archived": false,
#       "disabled": false,
#       "open_issues_count": 41,
#       "license": null,
#       "allow_forking": true,
#       "is_template": false,
#       "web_commit_signoff_required": false,
#       "topics": [
#         "data-science",
#         "deep-learning",
#         "machine-learning",
#         "natural-language-processing",
#         "python",
#         "reinforcement-learning"
#       ],
#       "visibility": "public",
#       "forks": 6349,
#       "open_issues": 41,
#       "watchers": 8392,
#       "default_branch": "master",
#       "permissions": {
#         "admin": false,
#         "maintain": false,
#         "push": false,
#         "triage": false,
#         "pull": true
#       },
#       "score": 1.0
#     },
#     {
#       "id": 155662306,
#       "node_id": "MDEwOlJlcG9zaXRvcnkxNTU2NjIzMDY=",
#       "name": "homemade-machine-learning",
#       "full_name": "trekhleb/homemade-machine-learning",
#       "private": false,
#       "owner": {
#         "login": "trekhleb",
#         "id": 3000285,
#         "node_id": "MDQ6VXNlcjMwMDAyODU=",
#         "avatar_url": "https://avatars.githubusercontent.com/u/3000285?v=4",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/trekhleb",
#         "html_url": "https://github.com/trekhleb",
#         "followers_url": "https://api.github.com/users/trekhleb/followers",
# ...
#       "issues_url": "https://api.github.com/repos/timzhang642/3D-Machine-Learning/issues{/number}",
#       "pulls_url": "https://api.github.com/repos/timzhang642/3D-Machine-Learning/pulls{/number}",
#       "milestones_url": "https://api.github.com/repos/timzhang642/3D-Machine-Learning/milestones{/number}",
#       "notifications_url": "https://api.github.com/repos/timzhang642/3D-Machine-Learning/notifications{?since,all,participating}",
#       "labels_url": "https://api.github.com/repos/timzhang642/3D-Machine-Learning/labels{/name}",
#       "releases_url": "https://api.github.com/repos/timzhang642/3D-Machine-Learning/releases{/id}",
#       "deployments_url": "https://api.github.com/repos/timzhang642/3D-Machine-Learning/deployments",
#       "created_at": "2017-08-12T15:20:54Z",
#       "updated_at": "2024-11-26T12:26:35Z",
#       "pushed_at": "2024-07-04T19:13:09Z",
#       "git_url": "git://github.com/timzhang642/3D-Machine-Learning.git",
#       "ssh_url": "git@github.com:timzhang642/3D-Machine-Learning.git",
#       "clone_url": "https://github.com/timzhang642/3D-Machine-Learning.git",
#       "svn_url": "https://github.com/timzhang642/3D-Machine-Learning",
#       "homepage": "",
#       "size": 24851,
#       "stargazers_count": 9790,
#       "watchers_count": 9790,
#       "language": null,
#       "has_issues": true,
#       "has_projects": true,
#       "has_downloads": true,
#       "has_wiki": true,
#       "has_pages": false,
#       "has_discussions": false,
#       "forks_count": 1788,
#       "mirror_url": null,
#       "archived": false,
#       "disabled": false,
#       "open_issues_count": 21,
#       "license": null,
#       "allow_forking": true,
#       "is_template": false,
#       "web_commit_signoff_required": false,
#       "topics": [
#         "3d",
#         "3d-reconstruction",
#         "constructive-solid-geometries",
#         "machine-learning",
#         "mesh",
#         "neural-networks",
#         "papers",
#         "point-cloud",
#         "primitives",
#         "voxel"
#       ],
#       "visibility": "public",
#       "forks": 1788,
#       "open_issues": 21,
#       "watchers": 9790,
#       "default_branch": "master",
#       "permissions": {
#         "admin": false,
#         "maintain": false,
#         "push": false,
#         "triage": false,
#         "pull": true
#       },
#       "score": 1.0
#     },
#     {
#       "id": 68511643,
#       "node_id": "MDEwOlJlcG9zaXRvcnk2ODUxMTY0Mw==",
#       "name": "MachineLearning",
#       "full_name": "carefree0910/MachineLearning",
#       "private": false,
#       "owner": {
#         "login": "carefree0910",
#         "id": 15677328,
#         "node_id": "MDQ6VXNlcjE1Njc3MzI4",
#         "avatar_url": "https://avatars.githubusercontent.com/u/15677328?v=4",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/carefree0910",
#         "html_url": "https://github.com/carefree0910",
#         "followers_url": "https://api.github.com/users/carefree0910/followers",
#         "following_url": "https://api.github.com/users/carefree0910/following{/other_user}",
#         "gists_url": "https://api.github.com/users/carefree0910/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/carefree0910/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/carefree0910/subscriptions",
#         "organizations_url": "https://api.github.com/users/carefree0910/orgs",
#         "repos_url": "https://api.github.com/users/carefree0910/repos",
#         "events_url": "https://api.github.com/users/carefree0910/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/carefree0910/received_events",
#         "type": "User",
#         "user_view_type": "public",
#         "site_admin": false
#       },
#       "html_url": "https://github.com/carefree0910/MachineLearning",
#       "description": "Machine learning algorithms implemented by pure numpy",
#       "fork": false,
#       "url": "https://api.github.com/repos/carefree0910/MachineLearning",
#       "forks_url": "https://api.github.com/repos/carefree0910/MachineLearning/forks",
#       "keys_url": "https://api.github.com/repos/carefree0910/MachineLearning/keys{/key_id}",
#       "collaborators_url": "https://api.github.com/repos/carefree0910/MachineLearning/collaborators{/collaborator}",
#       "teams_url": "https://api.github.com/repos/carefree0910/MachineLearning/teams",
#       "hooks_url": "https://api.github.com/repos/carefree0910/MachineLearning/hooks",
#       "issue_events_url": "https://api.github.com/repos/carefree0910/MachineLearning/issues/events{/number}",
#       "events_url": "https://api.github.com/repos/carefree0910/MachineLearning/events",
#       "assignees_url": "https://api.github.com/repos/carefree0910/MachineLearning/assignees{/user}",
#       "branches_url": "https://api.github.com/repos/carefree0910/MachineLearning/branches{/branch}",
#       "tags_url": "https://api.github.com/repos/carefree0910/MachineLearning/tags",
#       "blobs_url": "https://api.github.com/repos/carefree0910/MachineLearning/git/blobs{/sha}",
#       "git_tags_url": "https://api.github.com/repos/carefree0910/MachineLearning/git/tags{/sha}",
#       "git_refs_url": "https://api.github.com/repos/carefree0910/MachineLearning/git/refs{/sha}",
#       "trees_url": "https://api.github.com/repos/carefree0910/MachineLearning/git/trees{/sha}",
#       "statuses_url": "https://api.github.com/repos/carefree0910/MachineLearning/statuses/{sha}",
#       "languages_url": "https://api.github.com/repos/carefree0910/MachineLearning/languages",
#       "stargazers_url": "https://api.github.com/repos/carefree0910/MachineLearning/stargazers",
#       "contributors_url": "https://api.github.com/repos/carefree0910/MachineLearning/contributors",
#       "subscribers_url": "https://api.github.com/repos/carefree0910/MachineLearning/subscribers",
#       "subscription_url": "https://api.github.com/repos/carefree0910/MachineLearning/subscription",
#       "commits_url": "https://api.github.com/repos/carefree0910/MachineLearning/commits{/sha}",
#       "git_commits_url": "https://api.github.com/repos/carefree0910/MachineLearning/git/commits{/sha}",
#       "comments_url": "https://api.github.com/repos/carefree0910/MachineLearning/comments{/number}",
#       "issue_comment_url": "https://api.github.com/repos/carefree0910/MachineLearning/issues/comments{/number}",
#       "contents_url": "https://api.github.com/repos/carefree0910/MachineLearning/contents/{+path}",
#       "compare_url": "https://api.github.com/repos/carefree0910/MachineLearning/compare/{base}...{head}",
#       "merges_url": "https://api.github.com/repos/carefree0910/MachineLearning/merges",
#       "archive_url": "https://api.github.com/repos/carefree0910/MachineLearning/{archive_format}{/ref}",
#       "downloads_url": "https://api.github.com/repos/carefree0910/MachineLearning/downloads",
#       "issues_url": "https://api.github.com/repos/carefree0910/MachineLearning/issues{/number}",
#       "pulls_url": "https://api.github.com/repos/carefree0910/MachineLearning/pulls{/number}",
#       "milestones_url": "https://api.github.com/repos/carefree0910/MachineLearning/milestones{/number}",
#       "notifications_url": "https://api.github.com/repos/carefree0910/MachineLearning/notifications{?since,all,participating}",
#       "labels_url": "https://api.github.com/repos/carefree0910/MachineLearning/labels{/name}",
#       "releases_url": "https://api.github.com/repos/carefree0910/MachineLearning/releases{/id}",
#       "deployments_url": "https://api.github.com/repos/carefree0910/MachineLearning/deployments",
#       "created_at": "2016-09-18T09:37:01Z",
#       "updated_at": "2024-11-26T07:00:12Z",
#       "pushed_at": "2023-04-17T11:59:48Z",
#       "git_url": "git://github.com/carefree0910/MachineLearning.git",
#       "ssh_url": "git@github.com:carefree0910/MachineLearning.git",
#       "clone_url": "https://github.com/carefree0910/MachineLearning.git",
#       "svn_url": "https://github.com/carefree0910/MachineLearning",
#       "homepage": "https://mlblog.carefree0910.me",
#       "size": 54884,
#       "stargazers_count": 1068,
#       "watchers_count": 1068,
#       "language": "Jupyter Notebook",
#       "has_issues": true,
#       "has_projects": true,
#       "has_downloads": true,
#       "has_wiki": true,
#       "has_pages": false,
#       "has_discussions": false,
#       "forks_count": 723,
#       "mirror_url": null,
#       "archived": false,
#       "disabled": false,
#       "open_issues_count": 9,
#       "license": {
#         "key": "mit",
#         "name": "MIT License",
#         "spdx_id": "MIT",
#         "url": "https://api.github.com/licenses/mit",
#         "node_id": "MDc6TGljZW5zZTEz"
#       },
#       "allow_forking": true,
#       "is_template": false,
#       "web_commit_signoff_required": false,
#       "topics": [
#         "deep-learning",
#         "machine-learning",
#         "numpy",
#         "pytorch",
#         "tensorflow",
#         "visualization"
#       ],
#       "visibility": "public",
#       "forks": 723,
#       "open_issues": 9,
#       "watchers": 1068,
#       "default_branch": "master",
#       "permissions": {
#         "admin": false,
#         "maintain": false,
#         "push": false,
#         "triage": false,
#         "pull": true
#       },
#       "score": 1.0
#     },
#     {
#       "id": 177023075,
#       "node_id": "MDEwOlJlcG9zaXRvcnkxNzcwMjMwNzU=",
#       "name": "financial-machine-learning",
#       "full_name": "firmai/financial-machine-learning",
#       "private": false,
#       "owner": {
#         "login": "firmai",
#         "id": 26666267,
#         "node_id": "MDQ6VXNlcjI2NjY2MjY3",
#         "avatar_url": "https://avatars.githubusercontent.com/u/26666267?v=4",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/firmai",
#         "html_url": "https://github.com/firmai",
#         "followers_url": "https://api.github.com/users/firmai/followers",
#         "following_url": "https://api.github.com/users/firmai/following{/other_user}",
#         "gists_url": "https://api.github.com/users/firmai/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/firmai/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/firmai/subscriptions",
#         "organizations_url": "https://api.github.com/users/firmai/orgs",
#         "repos_url": "https://api.github.com/users/firmai/repos",
#         "events_url": "https://api.github.com/users/firmai/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/firmai/received_events",
#         "type": "User",
#         "user_view_type": "public",
#         "site_admin": false
#       },
#       "html_url": "https://github.com/firmai/financial-machine-learning",
#       "description": "A curated list of practical financial machine learning tools and applications.",
#       "fork": false,
#       "url": "https://api.github.com/repos/firmai/financial-machine-learning",
#       "forks_url": "https://api.github.com/repos/firmai/financial-machine-learning/forks",
#       "keys_url": "https://api.github.com/repos/firmai/financial-machine-learning/keys{/key_id}",
#       "collaborators_url": "https://api.github.com/repos/firmai/financial-machine-learning/collaborators{/collaborator}",
#       "teams_url": "https://api.github.com/repos/firmai/financial-machine-learning/teams",
#       "hooks_url": "https://api.github.com/repos/firmai/financial-machine-learning/hooks",
#       "issue_events_url": "https://api.github.com/repos/firmai/financial-machine-learning/issues/events{/number}",
#       "events_url": "https://api.github.com/repos/firmai/financial-machine-learning/events",
#       "assignees_url": "https://api.github.com/repos/firmai/financial-machine-learning/assignees{/user}",
#       "branches_url": "https://api.github.com/repos/firmai/financial-machine-learning/branches{/branch}",
#       "tags_url": "https://api.github.com/repos/firmai/financial-machine-learning/tags",
#       "blobs_url": "https://api.github.com/repos/firmai/financial-machine-learning/git/blobs{/sha}",
#       "git_tags_url": "https://api.github.com/repos/firmai/financial-machine-learning/git/tags{/sha}",
#       "git_refs_url": "https://api.github.com/repos/firmai/financial-machine-learning/git/refs{/sha}",
#       "trees_url": "https://api.github.com/repos/firmai/financial-machine-learning/git/trees{/sha}",
#       "statuses_url": "https://api.github.com/repos/firmai/financial-machine-learning/statuses/{sha}",
#       "languages_url": "https://api.github.com/repos/firmai/financial-machine-learning/languages",
#       "stargazers_url": "https://api.github.com/repos/firmai/financial-machine-learning/stargazers",
#       "contributors_url": "https://api.github.com/repos/firmai/financial-machine-learning/contributors",
#       "subscribers_url": "https://api.github.com/repos/firmai/financial-machine-learning/subscribers",
#       "subscription_url": "https://api.github.com/repos/firmai/financial-machine-learning/subscription",
#       "commits_url": "https://api.github.com/repos/firmai/financial-machine-learning/commits{/sha}",
#       "git_commits_url": "https://api.github.com/repos/firmai/financial-machine-learning/git/commits{/sha}",
#       "comments_url": "https://api.github.com/repos/firmai/financial-machine-learning/comments{/number}",
#       "issue_comment_url": "https://api.github.com/repos/firmai/financial-machine-learning/issues/comments{/number}",
#       "contents_url": "https://api.github.com/repos/firmai/financial-machine-learning/contents/{+path}",
#       "compare_url": "https://api.github.com/repos/firmai/financial-machine-learning/compare/{base}...{head}",
#       "merges_url": "https://api.github.com/repos/firmai/financial-machine-learning/merges",
#       "archive_url": "https://api.github.com/repos/firmai/financial-machine-learning/{archive_format}{/ref}",
#       "downloads_url": "https://api.github.com/repos/firmai/financial-machine-learning/downloads",
#       "issues_url": "https://api.github.com/repos/firmai/financial-machine-learning/issues{/number}",
#       "pulls_url": "https://api.github.com/repos/firmai/financial-machine-learning/pulls{/number}",
#       "milestones_url": "https://api.github.com/repos/firmai/financial-machine-learning/milestones{/number}",
#       "notifications_url": "https://api.github.com/repos/firmai/financial-machine-learning/notifications{?since,all,participating}",
#       "labels_url": "https://api.github.com/repos/firmai/financial-machine-learning/labels{/name}",
#       "releases_url": "https://api.github.com/repos/firmai/financial-machine-learning/releases{/id}",
#       "deployments_url": "https://api.github.com/repos/firmai/financial-machine-learning/deployments",
#       "created_at": "2019-03-21T21:00:35Z",
#       "updated_at": "2024-11-26T15:49:24Z",
#       "pushed_at": "2024-11-26T01:31:16Z",
#       "git_url": "git://github.com/firmai/financial-machine-learning.git",
#       "ssh_url": "git@github.com:firmai/financial-machine-learning.git",
#       "clone_url": "https://github.com/firmai/financial-machine-learning.git",
#       "svn_url": "https://github.com/firmai/financial-machine-learning",
#       "homepage": "https://www.sov.ai/",
#       "size": 6584,
#       "stargazers_count": 7266,
#       "watchers_count": 7266,
#       "language": "Python",
#       "has_issues": true,
#       "has_projects": true,
#       "has_downloads": true,
#       "has_wiki": true,
#       "has_pages": false,
#       "has_discussions": false,
#       "forks_count": 1268,
#       "mirror_url": null,
#       "archived": false,
#       "disabled": false,
#       "open_issues_count": 6,
#       "license": null,
#       "allow_forking": true,
#       "is_template": false,
#       "web_commit_signoff_required": false,
#       "topics": [
#         "algorithmic-trading",
#         "cryptocurrency",
#         "finance",
#         "investment",
#         "quant",
#         "quantitative-finance",
#         "stock-market",
#         "trading-strategies"
#       ],
#       "visibility": "public",
#       "forks": 1268,
#       "open_issues": 6,
#       "watchers": 7266,
#       "default_branch": "master",
#       "permissions": {
#         "admin": false,
#         "maintain": false,
#         "push": false,
#         "triage": false,
#         "pull": true
#       },
#       "score": 1.0
#     }
#   ]
# }

# %%
# Cell 6: Function to list commits
def list_commits(owner, repo, per_page=30, page=1):
    url = f'https://api.github.com/repos/{owner}/{repo}/commits'
    params = {
        'per_page': per_page,
        'page': page
    }
    response = requests.get(url, headers=headers, params=params)
    response.raise_for_status()
    return response.json()

# %%
# Cell 7: Test list_commits function
owner = 'octocat'  # Replace with any GitHub username
repo = 'Hello-World'  # Replace with any repository name
commits = list_commits(owner, repo)
print(json.dumps(commits, indent=2))
# Out:
# [
#   {
#     "sha": "7fd1a60b01f91b314f59955a4e4d4e80d8edf11d",
#     "node_id": "MDY6Q29tbWl0MTI5NjI2OTo3ZmQxYTYwYjAxZjkxYjMxNGY1OTk1NWE0ZTRkNGU4MGQ4ZWRmMTFk",
#     "commit": {
#       "author": {
#         "name": "The Octocat",
#         "email": "octocat@nowhere.com",
#         "date": "2012-03-06T23:06:50Z"
#       },
#       "committer": {
#         "name": "The Octocat",
#         "email": "octocat@nowhere.com",
#         "date": "2012-03-06T23:06:50Z"
#       },
#       "message": "Merge pull request #6 from Spaceghost/patch-1\n\nNew line at end of file.",
#       "tree": {
#         "sha": "b4eecafa9be2f2006ce1b709d6857b07069b4608",
#         "url": "https://api.github.com/repos/octocat/Hello-World/git/trees/b4eecafa9be2f2006ce1b709d6857b07069b4608"
#       },
#       "url": "https://api.github.com/repos/octocat/Hello-World/git/commits/7fd1a60b01f91b314f59955a4e4d4e80d8edf11d",
#       "comment_count": 86,
#       "verification": {
#         "verified": false,
#         "reason": "unsigned",
#         "signature": null,
#         "payload": null,
#         "verified_at": null
#       }
#     },
#     "url": "https://api.github.com/repos/octocat/Hello-World/commits/7fd1a60b01f91b314f59955a4e4d4e80d8edf11d",
#     "html_url": "https://github.com/octocat/Hello-World/commit/7fd1a60b01f91b314f59955a4e4d4e80d8edf11d",
#     "comments_url": "https://api.github.com/repos/octocat/Hello-World/commits/7fd1a60b01f91b314f59955a4e4d4e80d8edf11d/comments",
#     "author": {
#       "login": "octocat",
#       "id": 583231,
#       "node_id": "MDQ6VXNlcjU4MzIzMQ==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/583231?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false
#     },
#     "committer": {
#       "login": "octocat",
#       "id": 583231,
#       "node_id": "MDQ6VXNlcjU4MzIzMQ==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/583231?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false
#     },
#     "parents": [
#       {
#         "sha": "553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#         "url": "https://api.github.com/repos/octocat/Hello-World/commits/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#         "html_url": "https://github.com/octocat/Hello-World/commit/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e"
#       },
#       {
#         "sha": "762941318ee16e59dabbacb1b4049eec22f0d303",
#         "url": "https://api.github.com/repos/octocat/Hello-World/commits/762941318ee16e59dabbacb1b4049eec22f0d303",
#         "html_url": "https://github.com/octocat/Hello-World/commit/762941318ee16e59dabbacb1b4049eec22f0d303"
#       }
#     ]
#   },
#   {
#     "sha": "762941318ee16e59dabbacb1b4049eec22f0d303",
#     "node_id": "MDY6Q29tbWl0MTI5NjI2OTo3NjI5NDEzMThlZTE2ZTU5ZGFiYmFjYjFiNDA0OWVlYzIyZjBkMzAz",
#     "commit": {
#       "author": {
#         "name": "Johnneylee Jack Rollins",
#         "email": "Johnneylee.rollins@gmail.com",
#         "date": "2011-09-14T04:42:41Z"
#       },
#       "committer": {
#         "name": "Johnneylee Jack Rollins",
#         "email": "Johnneylee.rollins@gmail.com",
#         "date": "2011-09-14T04:42:41Z"
#       },
#       "message": "New line at end of file. --Signed off by Spaceghost",
#       "tree": {
#         "sha": "b4eecafa9be2f2006ce1b709d6857b07069b4608",
#         "url": "https://api.github.com/repos/octocat/Hello-World/git/trees/b4eecafa9be2f2006ce1b709d6857b07069b4608"
#       },
#       "url": "https://api.github.com/repos/octocat/Hello-World/git/commits/762941318ee16e59dabbacb1b4049eec22f0d303",
#       "comment_count": 168,
#       "verification": {
#         "verified": false,
#         "reason": "unsigned",
#         "signature": null,
#         "payload": null,
#         "verified_at": null
#       }
#     },
#     "url": "https://api.github.com/repos/octocat/Hello-World/commits/762941318ee16e59dabbacb1b4049eec22f0d303",
#     "html_url": "https://github.com/octocat/Hello-World/commit/762941318ee16e59dabbacb1b4049eec22f0d303",
#     "comments_url": "https://api.github.com/repos/octocat/Hello-World/commits/762941318ee16e59dabbacb1b4049eec22f0d303/comments",
#     "author": {
#       "login": "Spaceghost",
#       "id": 251370,
#       "node_id": "MDQ6VXNlcjI1MTM3MA==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/251370?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Spaceghost",
#       "html_url": "https://github.com/Spaceghost",
#       "followers_url": "https://api.github.com/users/Spaceghost/followers",
#       "following_url": "https://api.github.com/users/Spaceghost/following{/other_user}",
#       "gists_url": "https://api.github.com/users/Spaceghost/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/Spaceghost/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/Spaceghost/subscriptions",
#       "organizations_url": "https://api.github.com/users/Spaceghost/orgs",
#       "repos_url": "https://api.github.com/users/Spaceghost/repos",
#       "events_url": "https://api.github.com/users/Spaceghost/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/Spaceghost/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false
#     },
#     "committer": {
#       "login": "Spaceghost",
#       "id": 251370,
#       "node_id": "MDQ6VXNlcjI1MTM3MA==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/251370?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Spaceghost",
#       "html_url": "https://github.com/Spaceghost",
#       "followers_url": "https://api.github.com/users/Spaceghost/followers",
#       "following_url": "https://api.github.com/users/Spaceghost/following{/other_user}",
#       "gists_url": "https://api.github.com/users/Spaceghost/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/Spaceghost/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/Spaceghost/subscriptions",
#       "organizations_url": "https://api.github.com/users/Spaceghost/orgs",
#       "repos_url": "https://api.github.com/users/Spaceghost/repos",
#       "events_url": "https://api.github.com/users/Spaceghost/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/Spaceghost/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false
#     },
#     "parents": [
#       {
#         "sha": "553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#         "url": "https://api.github.com/repos/octocat/Hello-World/commits/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#         "html_url": "https://github.com/octocat/Hello-World/commit/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e"
#       }
#     ]
#   },
#   {
#     "sha": "553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#     "node_id": "MDY6Q29tbWl0MTI5NjI2OTo1NTNjMjA3N2YwZWRjM2Q1ZGM1ZDE3MjYyZjZhYTQ5OGU2OWQ2Zjhl",
#     "commit": {
#       "author": {
#         "name": "cameronmcefee",
#         "email": "cameron@github.com",
#         "date": "2011-01-26T19:06:08Z"
#       },
#       "committer": {
#         "name": "cameronmcefee",
#         "email": "cameron@github.com",
#         "date": "2011-01-26T19:06:08Z"
#       },
#       "message": "first commit",
#       "tree": {
#         "sha": "fcf4a9bba6857422971d67147517eb5edfdbf48d",
#         "url": "https://api.github.com/repos/octocat/Hello-World/git/trees/fcf4a9bba6857422971d67147517eb5edfdbf48d"
#       },
#       "url": "https://api.github.com/repos/octocat/Hello-World/git/commits/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#       "comment_count": 67,
#       "verification": {
#         "verified": false,
#         "reason": "unsigned",
#         "signature": null,
#         "payload": null,
#         "verified_at": null
#       }
#     },
#     "url": "https://api.github.com/repos/octocat/Hello-World/commits/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#     "html_url": "https://github.com/octocat/Hello-World/commit/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#     "comments_url": "https://api.github.com/repos/octocat/Hello-World/commits/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e/comments",
#     "author": {
#       "login": "Cameron423698",
#       "id": 94719050,
#       "node_id": "U_kgDOBaVMSg",
#       "avatar_url": "https://avatars.githubusercontent.com/u/94719050?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Cameron423698",
#       "html_url": "https://github.com/Cameron423698",
#       "followers_url": "https://api.github.com/users/Cameron423698/followers",
#       "following_url": "https://api.github.com/users/Cameron423698/following{/other_user}",
#       "gists_url": "https://api.github.com/users/Cameron423698/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/Cameron423698/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/Cameron423698/subscriptions",
#       "organizations_url": "https://api.github.com/users/Cameron423698/orgs",
#       "repos_url": "https://api.github.com/users/Cameron423698/repos",
#       "events_url": "https://api.github.com/users/Cameron423698/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/Cameron423698/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false
#     },
#     "committer": {
#       "login": "Cameron423698",
#       "id": 94719050,
#       "node_id": "U_kgDOBaVMSg",
#       "avatar_url": "https://avatars.githubusercontent.com/u/94719050?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Cameron423698",
#       "html_url": "https://github.com/Cameron423698",
#       "followers_url": "https://api.github.com/users/Cameron423698/followers",
#       "following_url": "https://api.github.com/users/Cameron423698/following{/other_user}",
#       "gists_url": "https://api.github.com/users/Cameron423698/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/Cameron423698/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/Cameron423698/subscriptions",
#       "organizations_url": "https://api.github.com/users/Cameron423698/orgs",
#       "repos_url": "https://api.github.com/users/Cameron423698/repos",
#       "events_url": "https://api.github.com/users/Cameron423698/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/Cameron423698/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false
#     },
#     "parents": []
#   }
# ]

# %%
# Cell 8: Function to get repository contents
def get_repository_contents(owner, repo, path=''):
    url = f'https://api.github.com/repos/{owner}/{repo}/contents/{path}'
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return response.json()

# %%
# Cell 9: Test get_repository_contents function
owner = 'octocat'  # Replace with any GitHub username
repo = 'Hello-World'  # Replace with any repository name
contents = get_repository_contents(owner, repo)
print(json.dumps(contents, indent=2))
# Out:
# [
#   {
#     "name": "README",
#     "path": "README",
#     "sha": "980a0d5f19a64b4b30a87d4206aade58726b60e3",
#     "size": 13,
#     "url": "https://api.github.com/repos/octocat/Hello-World/contents/README?ref=master",
#     "html_url": "https://github.com/octocat/Hello-World/blob/master/README",
#     "git_url": "https://api.github.com/repos/octocat/Hello-World/git/blobs/980a0d5f19a64b4b30a87d4206aade58726b60e3",
#     "download_url": "https://raw.githubusercontent.com/octocat/Hello-World/master/README",
#     "type": "file",
#     "_links": {
#       "self": "https://api.github.com/repos/octocat/Hello-World/contents/README?ref=master",
#       "git": "https://api.github.com/repos/octocat/Hello-World/git/blobs/980a0d5f19a64b4b30a87d4206aade58726b60e3",
#       "html": "https://github.com/octocat/Hello-World/blob/master/README"
#     }
#   }
# ]

# %%
# Cell 10: Function to fetch all pages
def fetch_all_pages(url, params=None):
    items = []
    while url:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        data = response.json()
        if 'items' in data:
            items.extend(data['items'])
        else:
            items.extend(data)

        if 'next' in response.links:
            url = response.links['next']['url']
            params = None
        else:
            url = None
    return items

# %%
# Cell 11: Test fetch_all_pages function
query = 'machine learning'
url = 'https://api.github.com/search/repositories'
params = {
    'q': query,
    'per_page': 100
}
all_repos = fetch_all_pages(url, params)
print(f'Total repositories fetched: {len(all_repos)}')
# Out:
# Total repositories fetched: 1000

# %%
# Cell 12: Function to check rate limit
def check_rate_limit():
    url = 'https://api.github.com/rate_limit'
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    data = response.json()
    remaining = data['resources']['core']['remaining']
    reset_time = data['resources']['core']['reset']
    reset_timestamp = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(reset_time))
    return remaining, reset_timestamp

# %%
# Cell 13: Test check_rate_limit function
remaining, reset_time = check_rate_limit()
print(f'Requests remaining: {remaining}')
print(f'Rate limit resets at: {reset_time}')
# Out:
# Requests remaining: 4994
# Rate limit resets at: 2024-11-26 17:39:02

# %%
# Cell 14: Safe request function with error handling
def safe_request(url, params=None):
    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        return response
    except requests.exceptions.HTTPError as http_err:
        status_code = response.status_code
        if status_code == 401:
            print('Error 401: Unauthorized. Check your authentication token.')
        elif status_code == 403:
            print('Error 403: Forbidden. You might have hit the rate limit.')
            remaining, reset_time = check_rate_limit()
            print(f'Requests remaining: {remaining}. Rate limit resets at: {reset_time}')
        elif status_code == 404:
            print('Error 404: Not Found. Check the URL and parameters.')
        else:
            print(f'HTTP error occurred: {http_err}')
    except Exception as err:
        print(f'An error occurred: {err}')
    return None

# %%
# Cell 15: Test safe_request function
url = 'https://api.github.com/repos/octocat/Hello-World/commits'
response = safe_request(url)
if response:
    commits = response.json()
    print(json.dumps(commits, indent=2))
else:
    print('Failed to retrieve data.')
# Out:
# [
#   {
#     "sha": "7fd1a60b01f91b314f59955a4e4d4e80d8edf11d",
#     "node_id": "MDY6Q29tbWl0MTI5NjI2OTo3ZmQxYTYwYjAxZjkxYjMxNGY1OTk1NWE0ZTRkNGU4MGQ4ZWRmMTFk",
#     "commit": {
#       "author": {
#         "name": "The Octocat",
#         "email": "octocat@nowhere.com",
#         "date": "2012-03-06T23:06:50Z"
#       },
#       "committer": {
#         "name": "The Octocat",
#         "email": "octocat@nowhere.com",
#         "date": "2012-03-06T23:06:50Z"
#       },
#       "message": "Merge pull request #6 from Spaceghost/patch-1\n\nNew line at end of file.",
#       "tree": {
#         "sha": "b4eecafa9be2f2006ce1b709d6857b07069b4608",
#         "url": "https://api.github.com/repos/octocat/Hello-World/git/trees/b4eecafa9be2f2006ce1b709d6857b07069b4608"
#       },
#       "url": "https://api.github.com/repos/octocat/Hello-World/git/commits/7fd1a60b01f91b314f59955a4e4d4e80d8edf11d",
#       "comment_count": 86,
#       "verification": {
#         "verified": false,
#         "reason": "unsigned",
#         "signature": null,
#         "payload": null,
#         "verified_at": null
#       }
#     },
#     "url": "https://api.github.com/repos/octocat/Hello-World/commits/7fd1a60b01f91b314f59955a4e4d4e80d8edf11d",
#     "html_url": "https://github.com/octocat/Hello-World/commit/7fd1a60b01f91b314f59955a4e4d4e80d8edf11d",
#     "comments_url": "https://api.github.com/repos/octocat/Hello-World/commits/7fd1a60b01f91b314f59955a4e4d4e80d8edf11d/comments",
#     "author": {
#       "login": "octocat",
#       "id": 583231,
#       "node_id": "MDQ6VXNlcjU4MzIzMQ==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/583231?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false
#     },
#     "committer": {
#       "login": "octocat",
#       "id": 583231,
#       "node_id": "MDQ6VXNlcjU4MzIzMQ==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/583231?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false
#     },
#     "parents": [
#       {
#         "sha": "553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#         "url": "https://api.github.com/repos/octocat/Hello-World/commits/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#         "html_url": "https://github.com/octocat/Hello-World/commit/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e"
#       },
#       {
#         "sha": "762941318ee16e59dabbacb1b4049eec22f0d303",
#         "url": "https://api.github.com/repos/octocat/Hello-World/commits/762941318ee16e59dabbacb1b4049eec22f0d303",
#         "html_url": "https://github.com/octocat/Hello-World/commit/762941318ee16e59dabbacb1b4049eec22f0d303"
#       }
#     ]
#   },
#   {
#     "sha": "762941318ee16e59dabbacb1b4049eec22f0d303",
#     "node_id": "MDY6Q29tbWl0MTI5NjI2OTo3NjI5NDEzMThlZTE2ZTU5ZGFiYmFjYjFiNDA0OWVlYzIyZjBkMzAz",
#     "commit": {
#       "author": {
#         "name": "Johnneylee Jack Rollins",
#         "email": "Johnneylee.rollins@gmail.com",
#         "date": "2011-09-14T04:42:41Z"
#       },
#       "committer": {
#         "name": "Johnneylee Jack Rollins",
#         "email": "Johnneylee.rollins@gmail.com",
#         "date": "2011-09-14T04:42:41Z"
#       },
#       "message": "New line at end of file. --Signed off by Spaceghost",
#       "tree": {
#         "sha": "b4eecafa9be2f2006ce1b709d6857b07069b4608",
#         "url": "https://api.github.com/repos/octocat/Hello-World/git/trees/b4eecafa9be2f2006ce1b709d6857b07069b4608"
#       },
#       "url": "https://api.github.com/repos/octocat/Hello-World/git/commits/762941318ee16e59dabbacb1b4049eec22f0d303",
#       "comment_count": 168,
#       "verification": {
#         "verified": false,
#         "reason": "unsigned",
#         "signature": null,
#         "payload": null,
#         "verified_at": null
#       }
#     },
#     "url": "https://api.github.com/repos/octocat/Hello-World/commits/762941318ee16e59dabbacb1b4049eec22f0d303",
#     "html_url": "https://github.com/octocat/Hello-World/commit/762941318ee16e59dabbacb1b4049eec22f0d303",
#     "comments_url": "https://api.github.com/repos/octocat/Hello-World/commits/762941318ee16e59dabbacb1b4049eec22f0d303/comments",
#     "author": {
#       "login": "Spaceghost",
#       "id": 251370,
#       "node_id": "MDQ6VXNlcjI1MTM3MA==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/251370?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Spaceghost",
#       "html_url": "https://github.com/Spaceghost",
#       "followers_url": "https://api.github.com/users/Spaceghost/followers",
#       "following_url": "https://api.github.com/users/Spaceghost/following{/other_user}",
#       "gists_url": "https://api.github.com/users/Spaceghost/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/Spaceghost/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/Spaceghost/subscriptions",
#       "organizations_url": "https://api.github.com/users/Spaceghost/orgs",
#       "repos_url": "https://api.github.com/users/Spaceghost/repos",
#       "events_url": "https://api.github.com/users/Spaceghost/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/Spaceghost/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false
#     },
#     "committer": {
#       "login": "Spaceghost",
#       "id": 251370,
#       "node_id": "MDQ6VXNlcjI1MTM3MA==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/251370?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Spaceghost",
#       "html_url": "https://github.com/Spaceghost",
#       "followers_url": "https://api.github.com/users/Spaceghost/followers",
#       "following_url": "https://api.github.com/users/Spaceghost/following{/other_user}",
#       "gists_url": "https://api.github.com/users/Spaceghost/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/Spaceghost/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/Spaceghost/subscriptions",
#       "organizations_url": "https://api.github.com/users/Spaceghost/orgs",
#       "repos_url": "https://api.github.com/users/Spaceghost/repos",
#       "events_url": "https://api.github.com/users/Spaceghost/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/Spaceghost/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false
#     },
#     "parents": [
#       {
#         "sha": "553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#         "url": "https://api.github.com/repos/octocat/Hello-World/commits/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#         "html_url": "https://github.com/octocat/Hello-World/commit/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e"
#       }
#     ]
#   },
#   {
#     "sha": "553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#     "node_id": "MDY6Q29tbWl0MTI5NjI2OTo1NTNjMjA3N2YwZWRjM2Q1ZGM1ZDE3MjYyZjZhYTQ5OGU2OWQ2Zjhl",
#     "commit": {
#       "author": {
#         "name": "cameronmcefee",
#         "email": "cameron@github.com",
#         "date": "2011-01-26T19:06:08Z"
#       },
#       "committer": {
#         "name": "cameronmcefee",
#         "email": "cameron@github.com",
#         "date": "2011-01-26T19:06:08Z"
#       },
#       "message": "first commit",
#       "tree": {
#         "sha": "fcf4a9bba6857422971d67147517eb5edfdbf48d",
#         "url": "https://api.github.com/repos/octocat/Hello-World/git/trees/fcf4a9bba6857422971d67147517eb5edfdbf48d"
#       },
#       "url": "https://api.github.com/repos/octocat/Hello-World/git/commits/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#       "comment_count": 67,
#       "verification": {
#         "verified": false,
#         "reason": "unsigned",
#         "signature": null,
#         "payload": null,
#         "verified_at": null
#       }
#     },
#     "url": "https://api.github.com/repos/octocat/Hello-World/commits/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#     "html_url": "https://github.com/octocat/Hello-World/commit/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e",
#     "comments_url": "https://api.github.com/repos/octocat/Hello-World/commits/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e/comments",
#     "author": {
#       "login": "Cameron423698",
#       "id": 94719050,
#       "node_id": "U_kgDOBaVMSg",
#       "avatar_url": "https://avatars.githubusercontent.com/u/94719050?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Cameron423698",
#       "html_url": "https://github.com/Cameron423698",
#       "followers_url": "https://api.github.com/users/Cameron423698/followers",
#       "following_url": "https://api.github.com/users/Cameron423698/following{/other_user}",
#       "gists_url": "https://api.github.com/users/Cameron423698/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/Cameron423698/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/Cameron423698/subscriptions",
#       "organizations_url": "https://api.github.com/users/Cameron423698/orgs",
#       "repos_url": "https://api.github.com/users/Cameron423698/repos",
#       "events_url": "https://api.github.com/users/Cameron423698/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/Cameron423698/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false
#     },
#     "committer": {
#       "login": "Cameron423698",
#       "id": 94719050,
#       "node_id": "U_kgDOBaVMSg",
#       "avatar_url": "https://avatars.githubusercontent.com/u/94719050?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Cameron423698",
#       "html_url": "https://github.com/Cameron423698",
#       "followers_url": "https://api.github.com/users/Cameron423698/followers",
#       "following_url": "https://api.github.com/users/Cameron423698/following{/other_user}",
#       "gists_url": "https://api.github.com/users/Cameron423698/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/Cameron423698/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/Cameron423698/subscriptions",
#       "organizations_url": "https://api.github.com/users/Cameron423698/orgs",
#       "repos_url": "https://api.github.com/users/Cameron423698/repos",
#       "events_url": "https://api.github.com/users/Cameron423698/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/Cameron423698/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false
#     },
#     "parents": []
#   }
# ]

# %%
# Cell 16: Complete data extraction example
def extract_data(query):
    remaining, reset_time = check_rate_limit()
    if remaining == 0:
        print(f'Rate limit exceeded. Waiting until {reset_time}.')
        return

    print(f"Searching repositories for query: '{query}'")
    url = 'https://api.github.com/search/repositories'
    params = {'q': query, 'per_page': 100}
    repositories = fetch_all_pages(url, params)
    print(f"Total repositories found: {len(repositories)}")

    for repo in repositories[:5]:
        owner = repo['owner']['login']
        repo_name = repo['name']
        print(f"\nRepository: {owner}/{repo_name}")

        print("Fetching commits...")
        commits_response = safe_request(f'https://api.github.com/repos/{owner}/{repo_name}/commits')
        if commits_response:
            commits = commits_response.json()
            print(f"Number of commits fetched: {len(commits)}")
        else:
            print("Failed to fetch commits.")

        print("Fetching repository contents...")
        contents_response = safe_request(f'https://api.github.com/repos/{owner}/{repo_name}/contents')
        if contents_response:
            contents = contents_response.json()
            print(f"Number of items in repository root: {len(contents)}")
        else:
            print("Failed to fetch contents.")

extract_data('machine learning')
# Out:
# Searching repositories for query: 'machine learning'
# Total repositories found: 1000
#
# Repository: josephmisiti/awesome-machine-learning
# Fetching commits...
# Number of commits fetched: 30
# Fetching repository contents...
# Number of items in repository root: 9
#
# Repository: wepe/MachineLearning
# Fetching commits...
# Number of commits fetched: 30
# Fetching repository contents...
# Number of items in repository root: 12
#
# Repository: Jack-Cherish/Machine-Learning
# Fetching commits...
# Number of commits fetched: 30
# Fetching repository contents...
# Number of items in repository root: 12
#
# Repository: lawlite19/MachineLearning_Python
# Fetching commits...
# Number of commits fetched: 30
# Fetching repository contents...
# Number of items in repository root: 13
#
# Repository: udacity/machine-learning
# Fetching commits...
# Number of commits fetched: 30
# Fetching repository contents...
# Number of items in repository root: 5
